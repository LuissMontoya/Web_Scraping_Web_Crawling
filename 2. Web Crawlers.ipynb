# %%
import urllib
from bs4 import BeautifulSoup

url = 'http://www-math.mit.edu/~gs/'
html = urllib.request.urlopen(url)
soup = BeautifulSoup(html)

tags = soup('a')

print('Enlaces de la página principal: \r\n')

for tag in tags:
    print(tag.contents[0], tag.get('href'))
    
print('\r\n Enlaces de las páginas secundarias: \r\n')
for tag in tags:
    newurl = tag.get('href')
    print('* Accediendo a los enlaces dentro de la página', newurl)
    try:
        if newurl[0:4]=='http': html2 = urllib.request.urlopen(newurl)
        else: html2 = urllib.request.urlopen(url+newurl)
        soup2 = BeautifulSoup(html2)    
        newtags = soup2('a')
        
        if len(newtags) > 0: 
            print(len(newtags), ' Enlaces:')
            for newtag in newtags:
                print(newtags.get('href'))
        else: print('No hay más enlaces')
    except:    
        print('Algo ha fallado')
# Out:
# Enlaces de la página principal:
#
# gilstrang@gmail.com mailto:gilstrang@gmail.com
# [read more bio] http://www-math.mit.edu/~gs/bio.html
# Curriculum Vitae http://www-math.mit.edu/~gs/vitae/cv.html
# 18.065 http://math.mit.edu/classes/18.065/2019SP
# <b>OCW</b> https://ocw.mit.edu/courses/mathematics/18-065-matrix-methods-in-data-analysis-signal-processing-and-machine-learning-spring-2018/
# <b>YouTube</b> https://www.youtube.com/watch?v=Cx5Z-OslNWE&list=PLUl4u3cNGP63oMNUHXqIUcrkS2PivhN3k
# 18.06 http://web.mit.edu/18.06/www
# 18.06 SC http://web.mit.edu/18.06/www
# ocw.mit.edu http://ocw.mit.edu/courses/mathematics/18-06sc-linear-algebra-fall-2011/
# Introduction to Linear Algebra http://math.mit.edu/~gs/linearalgebra/
# Linear Algebra for Everyone http://math.mit.edu/~gs/everyone/
# 18.085 https://math.mit.edu/classes/18.085/2018FA/index.html
# 18.086 http://www-math.mit.edu/18086/
# video lectures http://ocw.mit.edu/courses/mathematics/18-085-computational-science-and-engineering-i-fall-2008/video-lectures/
# CSE text https://math.mit.edu/cse
#  Highlights of Calculus http://ocw.mit.edu/resources/res-18-005-highlights-of-calculus-spring-2010/
# ocw.mit.edu http://ocw.mit.edu/courses/mathematics/18-085-computational-science-and-engineering-i-fall-2008/video-lectures/
# Mathworks.com http://www.mathworks.com/videos/series/differential-equations-and-linear-algebra-117657.html
# BYU ./videos/index.html
# Lecture Notes for Linear Algebra https://math.mit.edu/~gs/LectureNotes/
# Linear Algebra for Everyone (NEW 9/2020) http://math.mit.edu/~gs/everyone
# math.mit.edu/everyone http://math.mit.edu/~gs/everyone
# Linear Algebra and Learning from Data (2019) http://math.mit.edu/~gs/learningfromdata
# math.mit.edu/learningfromdata http://math.mit.edu/~gs/learningfromdata
# Introduction to Linear Algebra http://math.mit.edu/linearalgebra
# gilstrang@gmail.com mailto:gilstrang@gmail.com
# Complete List of Books and Articles  http://www-math.mit.edu/~gs/papers/papers.html
# Differential Equations and Linear Algebra http://math.mit.edu/dela/
# Computational Science and Engineering http://math.mit.edu/cse
# Wellesley-Cambridge Press (USA) website http://www.wellesleycambridge.com
# Wellesley Publishers (India) http://www.wellesleypublishers.com
# Accessibility https://accessibility.mit.edu
#
#  Enlaces de las páginas secundarias:
#
# * Accediendo a los enlaces dentro de la página mailto:gilstrang@gmail.com
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://www-math.mit.edu/~gs/bio.html
# 3  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://www-math.mit.edu/~gs/vitae/cv.html
# 45  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://math.mit.edu/classes/18.065/2019SP
# 8  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página https://ocw.mit.edu/courses/mathematics/18-065-matrix-methods-in-data-analysis-signal-processing-and-machine-learning-spring-2018/
# 131  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página https://www.youtube.com/watch?v=Cx5Z-OslNWE&list=PLUl4u3cNGP63oMNUHXqIUcrkS2PivhN3k
# 14  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://web.mit.edu/18.06/www
# No hay más enlaces
# * Accediendo a los enlaces dentro de la página http://web.mit.edu/18.06/www
# No hay más enlaces
# * Accediendo a los enlaces dentro de la página http://ocw.mit.edu/courses/mathematics/18-06sc-linear-algebra-fall-2011/
# 189  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://math.mit.edu/~gs/linearalgebra/
# 85  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://math.mit.edu/~gs/everyone/
# 33  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página https://math.mit.edu/classes/18.085/2018FA/index.html
# 14  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://www-math.mit.edu/18086/
# 68  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://ocw.mit.edu/courses/mathematics/18-085-computational-science-and-engineering-i-fall-2008/video-lectures/
# 212  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página https://math.mit.edu/cse
# 128  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://ocw.mit.edu/resources/res-18-005-highlights-of-calculus-spring-2010/
# 123  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://ocw.mit.edu/courses/mathematics/18-085-computational-science-and-engineering-i-fall-2008/video-lectures/
# 212  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://www.mathworks.com/videos/series/differential-equations-and-linear-algebra-117657.html
# 234  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página ./videos/index.html
# 1  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página https://math.mit.edu/~gs/LectureNotes/
# 32  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://math.mit.edu/~gs/everyone
# 33  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://math.mit.edu/~gs/everyone
# 33  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://math.mit.edu/~gs/learningfromdata
# 37  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://math.mit.edu/~gs/learningfromdata
# 37  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://math.mit.edu/linearalgebra
# 85  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página mailto:gilstrang@gmail.com
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://www-math.mit.edu/~gs/papers/papers.html
# 44  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://math.mit.edu/dela/
# 39  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://math.mit.edu/cse
# 128  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://www.wellesleycambridge.com
# 94  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página http://www.wellesleypublishers.com
# 22  Enlaces:
# Algo ha fallado
# * Accediendo a los enlaces dentro de la página https://accessibility.mit.edu
# 11  Enlaces:
# Algo ha fallado
